# %% [markdown]
# # NFL in-game win probability model
# * Develop a NFL in-game win probability model that calculates the probability of the possession club given the score
# differential and time remaining state
# * Catagorize scores states into groups of 7 points

# %%
# modules
import sys
import os
import pandas
import numpy
import datetime, time

import matplotlib.pyplot as plt
# %matplotlib notebook

import statsmodels.api as sm
from pylab import hist, show
import scipy
import statsmodels.api as sm

pandas.set_option("display.max_rows", 35)
pandas.set_option("display.max_columns", 50)
pandas.set_option("display.max_colwidth", 200)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
dm = pandas.read_csv('2013_nfl_pbp_data_through_wk_12.csv')
dm.head()
# Out:
#              gameid  qtr   min sec  off  def  down  togo  ydline  scorediff  \
# 0  20130905_BAL@DEN    1   NaN   0  DEN  BAL   NaN   NaN     NaN          0
# 1  20130905_BAL@DEN    1  60.0   0  BAL  DEN   1.0  10.0    80.0          0
# 2  20130905_BAL@DEN    1  59.0  14  BAL  DEN   2.0  11.0    81.0          0
# 3  20130905_BAL@DEN    1  58.0  38  BAL  DEN   3.0   8.0    78.0          0
# 4  20130905_BAL@DEN    1  58.0  18  BAL  DEN   4.0   2.0    72.0          0
#
#    series1stdn  \
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#
#                                                                                                                                               description  \
# 0                                                                                              M.Prater kicks 65 yards from DEN 35 to end zone Touchback.
# ...

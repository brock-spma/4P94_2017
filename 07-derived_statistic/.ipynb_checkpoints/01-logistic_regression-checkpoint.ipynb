# %% [markdown]
# # Derived statistics

# %% [markdown]
# ## Objectives
#
# * Understand the difference between summary and derived statistics
# * Implement data aggregation techniques to create a derived statistics
# * Measure the accuracy of a derived statistic
# * Report derived statistics across relevant catagories

# %% [markdown]
# ## Derived shot statistic
#
# * Develop a shot model to explain the likelihood a shot results in a goal
# * Develop an associated derived statistic
# * Measure the accuracy of the derived statistic
# * Report the derived statistics across teams

# %% [markdown]
# ## Wrist shot model and derived statistic

# %%
# %matplotlib inline
import os
import sys
import numpy 
import pandas 
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# !pip install plotly

# imports regression library
# OLS: ordinary least squares (estimation technique used to estimate the linear regression model)
import statsmodels.api as sm
from statsmodels.formula.api import ols
    
# Set some Pandas options
pandas.set_option('display.notebook_repr_html', True)
pandas.set_option('display.max_columns', 20)
pandas.set_option('display.max_rows', 50)

from decimal import getcontext, Decimal
# Set the precision.
getcontext().prec = 2

# %%
dm = pandas.read_csv('shots.csv')
dm = dm[(dm['advantagetypeshooter']=='EV')] 
dm = dm[dm['zone']=="O"]

# %% [markdown]
# ### Examine the data
# * XNorm is distance from center ice and YNorm from the middle of the ice.
# * Include relevant data in model

# %%
dm.head(2)
# Out:
#    season  gamenumber   gamedate vteamcode hteamcode  eventnumber  period  \
# 0    2011       20001  10/6/2011       PHI       BOS            4       1
# 1    2011       20001  10/6/2011       PHI       BOS            9       1
#
#    eventtimefromzero advantagetypeshooter advantagetypegoalie   ...     \
# 0                 47                   EV                  EV   ...
# 1                114                   EV                  EV   ...
#
#   position      namegoalie  tgoals ogoals  zone   X   Y  XNorm  YNorm shotType
# 0        G  BRYZGALOV_ILYA       0      0     O  32 -14     32    -14     Snap
# 1        G  BRYZGALOV_ILYA       0      0     O  37 -18     37    -18     Snap
#
# [2 rows x 25 columns]

# %%
dm.describe()
# Out:
#         season    gamenumber   eventnumber        period  eventtimefromzero  \
# count  57186.0  57186.000000  57186.000000  57186.000000        57186.00000
# mean    2011.0  20621.982094    154.552303      2.034432          584.16901
# std        0.0    354.047357     89.652301      0.850648          346.91897
# min     2011.0  20001.000000      3.000000      1.000000            4.00000
# 25%     2011.0  20318.000000     77.000000      1.000000          277.00000
# 50%     2011.0  20625.000000    154.000000      2.000000          573.00000
# 75%     2011.0  20928.000000    229.000000      3.000000          885.00000
# max     2011.0  21230.000000    392.000000      4.000000         1200.00000
#
#             isTHome  playernumber        tgoals        ogoals             X  \
# count  57186.000000  57186.000000  57186.000000  57186.000000  57186.000000
# mean       0.485433     29.926486      1.304480      1.180569      0.264016
# std        0.499792     13.608431      1.364192      1.280953     64.288069
# min        0.000000      1.000000      0.000000      0.000000    -99.000000
# 25%        0.000000     30.000000      0.000000      0.000000    -64.000000
# 50%        0.000000     31.000000      1.000000      1.000000     28.000000
# 75%        1.000000     35.000000      2.000000      2.000000     64.000000
# max        1.000000     70.000000      9.000000      9.000000     97.000000
#
#                   Y         XNorm         YNorm
# count  57186.000000  57186.000000  57186.000000
# mean      -0.178663     62.067604     -0.376613
# std       19.317856     16.750245     19.315011
# min      -42.000000     26.000000    -42.000000
# 25%      -15.000000     49.000000    -15.000000
# 50%        0.000000     64.000000     -1.000000
# 75%       14.000000     77.000000     14.000000
# max       42.000000     99.000000     42.000000

# %% [markdown]
# Examine shot length and type by goal scored

# %%
dm.groupby(['eventtype'])[['XNorm', 'YNorm']].describe()
# Out:
#              XNorm                                                      \
#              count       mean        std   min   25%   50%   75%   max
# eventtype
# GOAL        4678.0  70.962591  13.088705  27.0  64.0  75.0  81.0  97.0
# SHOT       52508.0  61.275139  16.811628  26.0  48.0  63.0  77.0  99.0
#
#              YNorm
#              count      mean        std   min   25%  50%   75%   max
# eventtype
# GOAL        4678.0 -0.132535  12.242820 -39.0  -6.0  0.0   6.0  40.0
# SHOT       52508.0 -0.398358  19.822985 -42.0 -16.0 -1.0  15.0  42.0

# %%
# Similar table as above. Swapped axes for easy of display

_t = dm.groupby(['eventtype'])[['XNorm', 'YNorm']].describe()
_t.swapaxes(0,1)
# Out:
# eventtype           GOAL          SHOT
# XNorm count  4678.000000  52508.000000
#       mean     70.962591     61.275139
#       std      13.088705     16.811628
#       min      27.000000     26.000000
#       25%      64.000000     48.000000
#       50%      75.000000     63.000000
#       75%      81.000000     77.000000
#       max      97.000000     99.000000
# YNorm count  4678.000000  52508.000000
#       mean     -0.132535     -0.398358
#       std      12.242820     19.822985
#       min     -39.000000    -42.000000
#       25%      -6.000000    -16.000000
#       50%       0.000000     -1.000000
#       75%       6.000000     15.000000
#       max      40.000000     42.000000

# %% [markdown]
# ### Pivot table
# * shot type by event type

# %%
pandas.crosstab(dm['shotType'], dm['eventtype'], margins=True)
# Out:
# eventtype    GOAL   SHOT    All
# shotType
# Backhand      513   4709   5222
# Deflected     172    701    873
# Slap          545  10716  11261
# Snap          681   7574   8255
# Tip-In        432   1927   2359
# Wrap-around    49    897    946
# Wrist        2286  25984  28270
# All          4678  52508  57186

# %%
# cross table normalized values
pandas.crosstab(dm['shotType'], dm['eventtype'], margins=True, normalize=True)
# Out:
# eventtype        GOAL      SHOT       All
# shotType
# Backhand     0.008971  0.082345  0.091316
# Deflected    0.003008  0.012258  0.015266
# Slap         0.009530  0.187389  0.196919
# Snap         0.011909  0.132445  0.144354
# Tip-In       0.007554  0.033697  0.041251
# Wrap-around  0.000857  0.015686  0.016543
# Wrist        0.039975  0.454377  0.494352
# All          0.081803  0.918197  1.000000

# %% [markdown]
# ### Create variables

# %%
dm['isgoal'] = dm['eventtype']=='GOAL'
dm['XNormAdj'] = 99 - dm['XNorm']
dm.groupby(['eventtype'])[['XNormAdj', 'YNorm']].describe()
# Out:
#           XNormAdj                                                     \
#              count       mean        std  min   25%   50%   75%   max
# eventtype
# GOAL        4678.0  28.037409  13.088705  2.0  18.0  24.0  35.0  72.0
# SHOT       52508.0  37.724861  16.811628  0.0  22.0  36.0  51.0  73.0
#
#              YNorm
#              count      mean        std   min   25%  50%   75%   max
# eventtype
# GOAL        4678.0 -0.132535  12.242820 -39.0  -6.0  0.0   6.0  40.0
# SHOT       52508.0 -0.398358  19.822985 -42.0 -16.0 -1.0  15.0  42.0

# %%
dm['XNormAdj'] = dm['XNormAdj'] + 1
dm['YNormAdj'] = numpy.absolute(dm['YNorm'])
dm['YNormAdj'] = dm['YNormAdj'] + 1

dm['lnX'] = numpy.log(dm['XNormAdj'])
dm['lnY'] = numpy.log(dm['YNormAdj'])

dm['dscore'] = dm['tgoals'] - dm['ogoals']
dm['oteamcode'] = dm.apply(lambda x: 1 if (x['teamcode'] == x['hteamcode']) else x['vteamcode'], axis=1)

# %% [markdown]
# ### Create wrist shot specific data frame

# %%
dw = dm[dm['shotType']=='Wrist']

# %% [markdown]
# ### Heat map
# * a representation of data in the form of a map or diagram in which data values are represented as colors

# %%
# Shots and goals
plt.hist2d(dw['XNormAdj'], dw['YNorm'],bins=30)
plt.show()

# %%
# Only goals
dg = dw[dw['eventtype']=='GOAL']
plt.hist2d(dg['XNormAdj'], dg['YNorm'],bins=30)
plt.show()

# %% [markdown]
# ### Logit regression
#
# Linear probability models (i.e., OLS) can predict probabilties outside of the 0-1 interval. A logistic regression estimates the log odds relationship. The resultant probabilities are bound between 0 and 1:
#
# $$ p_i = \frac{1}{1+exp(-X'\beta)}$$
#
# The paramater estimates are in terms of log odds. Marginal effects represent unit change increments similar to OLS.

# %% [markdown]
# Model the probability that a shot results in a goal in terms of length.

# %% [markdown]
# ### Model specifications
# * m1: length
# * m2: width
# * m3: length and width

# %%
# specification: m1: length
# estimation procedure
m1 = sm.Logit(dw['isgoal'], sm.add_constant(dw['lnX'])).fit()

# marginal effects
m1.get_margeff(method='dydx', at='overall').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.266436
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lnX           -0.0993      0.004    -26.341      0.000      -0.107      -0.092
# ==============================================================================
# """

# %% [markdown]
# Each percent increase in length from the net decrease the probability of a goal by 0.10

# %%
# Predicted values
dw['pgoalx'] = m1.predict()

# plot predicted values
dw.plot(kind='scatter',x='XNormAdj', y='pgoalx')
# Out:
# /Users/kmongeon/anaconda3/envs/new_root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# specification: m1: width
 #Model the probability that a shot results in a goal in terms of width

m2 = sm.Logit(dw['isgoal'], sm.add_constant(dw['lnY'])).fit()
m2.get_margeff(method='dydx', at='overall').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.262135
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lnY           -0.0515      0.002    -31.054      0.000      -0.055      -0.048
# ==============================================================================
# """

# %% [markdown]
# Each percent increase in width decreases the probability of a goal by 0.05.

# %%
# predicted values
dw['pgoaly'] = m1.predict()

# plot
dw.plot(kind='scatter', x='YNormAdj', y='pgoaly')
# Out:
# /Users/kmongeon/anaconda3/envs/new_root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# specification m3: length and width
# Model the probability that a shot results in a goal in terms of length and width

m3 = sm.Logit(dw['isgoal'], sm.add_constant(dw[['lnX', 'lnY']])).fit()
m3.get_margeff(method='dydx', at='overall').summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.253262
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# lnX           -0.0802      0.004    -21.382      0.000      -0.088      -0.073
# lnY           -0.0451      0.002    -26.731      0.000      -0.048      -0.042
# ==============================================================================
# """

# %% [markdown]
# Each percent increase in length and width decreases the probability of a goal by 0.80 and 0.05, respectively.

# %%
# predict values
dw['pgoal'] = m3.predict()
# Out:
# /Users/kmongeon/anaconda3/envs/new_root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Data aggregation
# * Aggregate data across relevant in-game factors to discern accuracy of prediction relative to actual goals scored

# %%
dw.describe()
# Out:
#         season    gamenumber   eventnumber        period  eventtimefromzero  \
# count  28270.0  28270.000000  28270.000000  28270.000000       28270.000000
# mean    2011.0  20618.290838    154.428405      2.029360         583.099965
# std        0.0    355.034852     89.752143      0.849111         347.823294
# min     2011.0  20001.000000      3.000000      1.000000           5.000000
# 25%     2011.0  20313.000000     76.000000      1.000000         275.000000
# 50%     2011.0  20619.000000    154.000000      2.000000         572.000000
# 75%     2011.0  20928.000000    229.000000      3.000000         886.000000
# max     2011.0  21230.000000    387.000000      4.000000        1200.000000
#
#             isTHome  playernumber        tgoals        ogoals             X  \
# count  28270.000000  28270.000000  28270.000000  28270.000000  28270.000000
# mean       0.489317     29.649699      1.301309      1.178811      0.275345
# std        0.499895     13.714211      1.363521      1.280928     65.675970
# min        0.000000      1.000000      0.000000      0.000000    -99.000000
# 25%        0.000000     30.000000      0.000000      0.000000    -65.000000
# 50%        0.000000     31.000000      1.000000      1.000000     27.000000
# 75%        1.000000     35.000000      2.000000      2.000000     66.000000
# max        1.000000     70.000000      9.000000      9.000000     97.000000
#
#            ...              XNorm         YNorm      XNormAdj      YNormAdj  \
# count      ...       28270.000000  28270.000000  28270.000000  28270.000000
# mean       ...          63.838274     -0.162115     36.161726     17.217297
# std        ...          15.425286     19.680202     15.425286     11.150183
# min        ...          26.000000    -42.000000      1.000000      1.000000
# 25%        ...          53.000000    -15.000000     23.000000      7.000000
# 50%        ...          66.000000      0.000000     34.000000     16.000000
# 75%        ...          77.000000     14.000000     47.000000     26.000000
# max        ...          99.000000     42.000000     74.000000     43.000000
#
#                 lnX           lnY        dscore        pgoalx        pgoaly  \
# count  28270.000000  28270.000000  28270.000000  28270.000000  28270.000000
# mean       3.490792      2.538505      0.122497      0.080863      0.080863
# std        0.452744      0.895111      1.511693      0.048679      0.048679
# min        0.000000      0.000000     -9.000000      0.023750      0.023750
# 25%        3.135494      1.945910     -1.000000      0.043531      0.043531
# 50%        3.526361      2.772589      0.000000      0.066422      0.066422
# 75%        3.850148      3.258097      1.000000      0.108743      0.108743
# max        4.304065      3.761200      9.000000      0.902288      0.902288
#
#               pgoal
# count  28270.000000
# mean       0.080863
# std        0.068736
# min        0.011903
# 25%        0.029548
# 50%        0.054366
# 75%        0.112995
# max        0.753224
#
# [8 rows x 21 columns]

# %%
# season
dw.groupby(['season'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal   pgoal
# season
# 2011    2286.0  2286.0

# %%
# period
dw.groupby(['period'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# period
# 1        698.0  729.987912
# 2        783.0  772.139430
# 3        763.0  739.005024
# 4         42.0   44.867634

# %%
# score differential
dw.groupby(['dscore'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# dscore
# -9         0.0    0.032141
# -8         0.0    0.049956
# -7         1.0    0.559587
# -6         5.0    1.672141
# -5         6.0    7.157355
# -4        32.0   26.720097
# -3        71.0   67.201627
# -2       178.0  158.832162
# -1       412.0  369.062586
#  0       830.0  856.355194
#  1       424.0  454.056756
#  2       221.0  215.406142
#  3        69.0   84.226306
#  4        28.0   30.658224
#  5         6.0    9.224899
#  6         2.0    2.717579
#  7         1.0    1.773359
#  8         0.0    0.274875
#  9         0.0    0.019014

# %% [markdown]
# ### Data aggregation
# Aggregate data across factors of interest to discern quality of play
# * teamcode is defensive team
# * oteamcode is offensive team

# %%
# defensive team
dw.groupby(['teamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#           isgoal      pgoal
# teamcode
# ANA         70.0  79.426708
# BOS         70.0  67.076469
# BUF         69.0  70.938178
# CAR         80.0  78.959440
# CBJ         96.0  82.801399
# CGY         70.0  81.062313
# CHI         95.0  88.812515
# COL         89.0  82.050795
# DAL         81.0  78.217177
# DET         73.0  72.198869
# EDM         71.0  73.998327
# FLA         68.0  67.029186
# LA          70.0  67.985942
# MIN         82.0  74.127990
# MTL         86.0  80.923262
# NJ          63.0  51.474305
# NSH         75.0  84.576630
# NYI         83.0  82.097201
# NYR         54.0  72.654261
# OTT         90.0  83.259913
# PHI         69.0  70.971619
# PHX         78.0  90.744282
# PIT         86.0  76.695336
# SJ          66.0  68.293781
# STL         46.0  74.834860
# TB         103.0  81.656420
# TOR         88.0  71.868760
# VAN         66.0  83.574829
# WPG         68.0  66.914251
# WSH         81.0  80.774981

# %%
# offensive team
dw.groupby(['oteamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#            isgoal        pgoal
# oteamcode
# 1          1108.0  1094.181785
# ANA          30.0    38.420760
# BOS          38.0    36.601831
# BUF          38.0    38.172644
# CAR          49.0    46.964787
# CBJ          49.0    41.363198
# CGY          36.0    41.553127
# CHI          47.0    41.977832
# COL          39.0    38.897836
# DAL          33.0    41.586152
# DET          46.0    40.329039
# EDM          48.0    47.659398
# FLA          47.0    41.921513
# LA           35.0    36.740647
# MIN          33.0    39.656652
# MTL          37.0    36.096784
# NJ           38.0    32.963143
# NSH          36.0    42.209827
# NYI          37.0    39.343142
# NYR          32.0    37.196194
# OTT          42.0    40.681789
# PHI          32.0    35.929709
# PHX          39.0    39.850537
# PIT          40.0    37.606783
# SJ           38.0    36.230134
# STL          28.0    42.652301
# TB           52.0    42.815700
# TOR          42.0    45.029917
# VAN          32.0    36.778852
# WPG          41.0    39.649233
# WSH          44.0    34.938753

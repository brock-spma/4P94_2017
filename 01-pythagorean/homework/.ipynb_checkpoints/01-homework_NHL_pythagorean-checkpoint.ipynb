# %% [markdown]
# # Objective
#
# Use the csv file titled NHL_season_team_goals.csv to:
# * Calculate team win percentages: $winper=\frac{W}{W+L}$
# * Calculate team expected win percentages based on the origonal Pythagoream formula: $\widehat{winper}=\frac{GF^2}{GF^2+ GA^2}$
# * Compare the actual and expected team win percentages

# %%
# system
import os
import sys

# Data management
import pandas 
import numpy

# Plots
import matplotlib.pyplot as plt
import bokeh
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a132644f-461e-4617-bf4d-f89f328c42b7">Loading BokehJS ...</span>
#     </div>

# %%
dm = pandas.read_csv('NHL_season_team_goals.csv')
dm.head()
# Out:
#   Team  GamesPlayed  GoalsFor  GoalsAllowed  Wins  Losses
# 0  ANA           82       235           233    47      35
# 1  ATL           82       218           262    34      48
# 2  BOS           82       244           189    46      36
# 3  BUF           82       240           228    43      39
# 4  CAR           82       231           234    40      42

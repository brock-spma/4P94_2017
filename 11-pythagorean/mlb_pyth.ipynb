# %% [markdown]
# # Structure of analysis
# - Objective
# - Modules
# - Import
# - Clean
# - Organize
# - Generate
# - Analyze
#   * Summary (i.e., descriptive) analysis
#     * descriptive statistics
#     * visualize
#   * Model
#     * Describe the underlyting data generating process
#
# Resources
# * See pandas options: https://pandas.pydata.org/pandas-docs/stable/options.html

# %% [markdown]
# # Objective
#
# 1. Calculate team win percentages: $winper=\frac{W}{W+L}$
# 2. Calculate team expected win percentages based on the origonal Pythagoream formula: $\widehat{winper}=\frac{RF^2}{RF^2+ RA^2}$
# 3. Save datafram as csv in working directory

# %% [markdown]
# ## Modules

# %%
# system
import os
import sys

# Data management
import pandas 
import numpy

# Plots
import matplotlib.pyplot as plt
import bokeh
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5696888c-c478-4973-ba70-d4db2888131b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Import data

# %%
# observe working directory
os.getcwd()
# Out:
# 'C:\\Users\\kmongeon\\Documents\\GIT\\4P94_2017\\01-pythagorean'

# %%
# Obtain data
# convert csv to dataframe
# view first 5 rows
dm = pandas.read_csv('mlb_win.csv')
dm.head()
# Out:
#                     Team League   W   L  Runs For  Runs Against
# 0  Philadelphia Phillies     NL  63  99       626           809
# 1        Cincinnati Reds     NL  64  98       641           754
# 2         Atlanta Braves     NL  67  95       573           760
# 3       Colorado Rockies     NL  68  94       737           844
# 4      Milwaukee Brewers     NL  68  94       655           738

# %%
# view last 5 rows
dm.tail()
# Out:
#                    Team League    W   L  Runs For  Runs Against
# 25    Toronto Blue Jays     AL   93  69       891           670
# 26   Kansas City Royals     AL   95  67       724           641
# 27         Chicago Cubs     NL   97  65       689           608
# 28   Pittsburgh Pirates     NL   98  64       697           596
# 29  St. Louis Cardinals     NL  100  62       647           525

# %%
# View data
dm
# Out:
#                      Team League    W   L  Runs For  Runs Against
# 0   Philadelphia Phillies     NL   63  99       626           809
# 1         Cincinnati Reds     NL   64  98       641           754
# 2          Atlanta Braves     NL   67  95       573           760
# 3        Colorado Rockies     NL   68  94       737           844
# 4       Milwaukee Brewers     NL   68  94       655           738
# 5       Oakland Athletics     AL   68  94       694           729
# 6           Miami Marlins     NL   71  91       613           678
# 7        San Diego Padres     NL   74  88       650           731
# 8          Detroit Tigers     AL   74  87       689           803
# 9       Chicago White Sox     AL   76  86       622           701
# 10       Seattle Mariners     AL   76  86       656           726
# 11         Boston Red Sox     AL   78  84       748           753
# 12   Arizona Diamondbacks     NL   79  83       720           713
# 13         Tampa Bay Rays     AL   80  82       644           642
# 14      Baltimore Orioles     AL   81  81       713           693
# 15      Cleveland Indians     AL   81  80       669           640
# 16        Minnesota Twins     AL   83  79       696           700
# 17   Washington Nationals     NL   83  79       703           635
# 18   San Francisco Giants     NL   84  78       696           627
# 19     Los Angeles Angels     AL   85  77       661           675
# 20         Houston Astros     AL   86  76       729           618
# 21       New York Yankees     AL   87  75       764           698
# 22          Texas Rangers     AL   88  74       751           733
# 23          New York Mets     NL   90  72       683           613
# 24    Los Angeles Dodgers     NL   92  70       667           595
# 25      Toronto Blue Jays     AL   93  69       891           670
# 26     Kansas City Royals     AL   95  67       724           641
# 27           Chicago Cubs     NL   97  65       689           608
# 28     Pittsburgh Pirates     NL   98  64       697           596
# 29    St. Louis Cardinals     NL  100  62       647           525

# %%
# length of dataframe
len(dm)
# Out:
# 30

# %% [markdown]
# ## Clean

# %%
dm.columns
# Out:
# Index(['Team', 'League', 'W', 'L', 'Runs For', 'Runs Against'], dtype='object')

# %%
dm.dtypes
# Out:
# Team            object
# League          object
# W                int64
# L                int64
# Runs For         int64
# Runs Against     int64
# dtype: object

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
# Team            30 non-null object
# League          30 non-null object
# W               30 non-null int64
# L               30 non-null int64
# Runs For        30 non-null int64
# Runs Against    30 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Organize
# * organize columns logically
# * organize columns relative to the data hierarchy
# * sort data relative to objective
# * sort data relative to hierarchy

# %%
dm = dm.sort_values(by=['League', 'Team'])
dm.head()
# Out:
#                  Team League   W   L  Runs For  Runs Against
# 14  Baltimore Orioles     AL  81  81       713           693
# 11     Boston Red Sox     AL  78  84       748           753
# 9   Chicago White Sox     AL  76  86       622           701
# 15  Cleveland Indians     AL  81  80       669           640
# 8      Detroit Tigers     AL  74  87       689           803

# %% [markdown]
# ## Generate variable for analysis
# * Dataframe refers to variables as columns

# %%
# rename columns (exclude spaces and symbols)
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html
dm = dm.rename(columns={'Runs For': "RF", "Runs Against": "RA"})

# Difference in runs scored and allowed
dm['DR'] = dm.RF - dm.RA

#Winning percentage
dm['WP']  = dm['W'] / (dm['W']  + dm['L'] )

# Runs for squared
# Run allowed squared
dm['RF2'] = dm['RF']**2
dm['RA2'] = dm['RA']**2
dm['DR2'] = dm.RF2 - dm.RA2
dm.head()
# Out:
#                  Team League   W   L   RF   RA   DR        WP     RF2     RA2  \
# 14  Baltimore Orioles     AL  81  81  713  693   20  0.500000  508369  480249
# 11     Boston Red Sox     AL  78  84  748  753   -5  0.481481  559504  567009
# 9   Chicago White Sox     AL  76  86  622  701  -79  0.469136  386884  491401
# 15  Cleveland Indians     AL  81  80  669  640   29  0.503106  447561  409600
# 8      Detroit Tigers     AL  74  87  689  803 -114  0.459627  474721  644809
#
#        DR2
# 14   28120
# 11   -7505
# 9  -104517
# 15   37961
# 8  -170088

# %% [markdown]
# # Analysis
# * Examine relationships
#   * Dependant and independent variables

# %% [markdown]
# ## Summary statistics

# %%
dm.describe()
# Out:
#                 W          L          RF          RA          DR         WP  \
# count   30.000000  30.000000   30.000000   30.000000   30.000000  30.000000
# mean    80.966667  80.966667  688.266667  688.266667    0.000000   0.499992
# std     10.453455  10.433644   58.733726   72.131553   94.884685   0.064467
# min     63.000000  62.000000  573.000000  525.000000 -187.000000   0.388889
# 25%     74.000000  74.250000  651.250000  636.250000  -76.750000   0.457499
# 50%     81.000000  80.500000  689.000000  695.500000    4.500000   0.501553
# 75%     87.750000  87.750000  718.250000  732.500000   69.750000   0.541667
# max    100.000000  99.000000  891.000000  844.000000  221.000000   0.617284
#
#                  RF2            RA2            DR2
# count      30.000000      30.000000      30.000000
# mean   477045.666667  478740.533333   -1694.866667
# std     84973.570284   99732.717204  133614.223107
# min    328329.000000  275625.000000 -262605.000000
# 25%    424131.250000  404818.750000 -102572.750000
# 50%    474721.000000  483726.500000    6301.500000
# 75%    515892.250000  536557.000000   91211.250000
# max    793881.000000  712336.000000  344981.000000

# %% [markdown]
# # Plots

# %%
# define figure and set attributes
p = figure(plot_width=700, plot_height=400, y_range=(0, 1))

# add a circle renderer with a size, color, and alpha
p.circle(dm.RF, dm.WP, size=5, color="black", alpha=0.5)
p.circle(dm.RA, dm.WP, size=5, color="firebrick", alpha=0.5 )

# show the results
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e9f3f36e-edfb-496c-a8d9-523f8fd1c930"></div>
# </div>

# %%
p1 = figure(plot_width=400, plot_height=400, y_range=(0, 1))
p1.circle(dm.DR, dm.WP, size=5, color="black", alpha=0.5)

p2 = figure(plot_width=400, plot_height=400, y_range=(0, 1))
p2.circle(dm.DR2, dm.WP, size=5, color="firebrick", alpha=0.5)

# show the results
show(row(p1, p2))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0c52a027-ad7d-4303-8f9b-a0065a30ffa8"></div>
# </div>

# %% [markdown]
# ##  Model
# Expected winning percentage: $\widehat{winper}=\frac{RF^2}{RF^2+ RA^2}$

# %%
# Expected winning percentage
dm['EWP'] = dm['RF2'] / (dm['RF2']+ dm['RA2'] )

# Expected versus actual winning percentage
dm['Diff'] = dm['WP']  - dm['EWP']
dm.head()
# Out:
#                  Team League   W   L   RF   RA   DR        WP     RF2     RA2  \
# 14  Baltimore Orioles     AL  81  81  713  693   20  0.500000  508369  480249
# 11     Boston Red Sox     AL  78  84  748  753   -5  0.481481  559504  567009
# 9   Chicago White Sox     AL  76  86  622  701  -79  0.469136  386884  491401
# 15  Cleveland Indians     AL  81  80  669  640   29  0.503106  447561  409600
# 8      Detroit Tigers     AL  74  87  689  803 -114  0.459627  474721  644809
#
#        DR2       EWP      Diff
# 14   28120  0.514222 -0.014222
# 11   -7505  0.496669 -0.015187
# 9  -104517  0.440499  0.028636
# 15   37961  0.522143 -0.019038
# 8  -170088  0.424036  0.035591

# %%
# sort data relative to winning percentage in ascending order 
dm = dm.sort_values(by=['WP'], ascending=True)

# display relavant columns  
dm[['Team', 'WP', 'EWP']]
# Out:
#                      Team        WP       EWP
# 0   Philadelphia Phillies  0.388889  0.374515
# 1         Cincinnati Reds  0.395062  0.419524
# 2          Atlanta Braves  0.413580  0.362422
# 4       Milwaukee Brewers  0.419753  0.440627
# 3        Colorado Rockies  0.419753  0.432630
# 5       Oakland Athletics  0.419753  0.475419
# 6           Miami Marlins  0.438272  0.449779
# 7        San Diego Padres  0.456790  0.441548
# 8          Detroit Tigers  0.459627  0.424036
# 9       Chicago White Sox  0.469136  0.440499
# 10       Seattle Mariners  0.469136  0.449478
# 11         Boston Red Sox  0.481481  0.496669
# 12   Arizona Diamondbacks  0.487654  0.504885
# 13         Tampa Bay Rays  0.493827  0.501555
# 14      Baltimore Orioles  0.500000  0.514222
# 15      Cleveland Indians  0.503106  0.522143
# 17   Washington Nationals  0.512346  0.550691
# 16        Minnesota Twins  0.512346  0.497135
# 18   San Francisco Giants  0.518519  0.552013
# 19     Los Angeles Angels  0.524691  0.489522
# 20         Houston Astros  0.530864  0.581850
# 21       New York Yankees  0.537037  0.545052
# 22          Texas Rangers  0.543210  0.512128
# 23          New York Mets  0.555556  0.553855
# 24    Los Angeles Dodgers  0.567901  0.556867
# 25      Toronto Blue Jays  0.574074  0.638794
# 26     Kansas City Royals  0.586420  0.560582
# 27           Chicago Cubs  0.598765  0.562209
# 28     Pittsburgh Pirates  0.604938  0.577639
# 29    St. Louis Cardinals  0.617284  0.602980

# %%
# Plot winning percentage in terms of expected winning
p = figure(plot_width=700, plot_height=400, y_range=(0, 1))
p.circle(dm.WP, dm.EWP, size=5, color="black", alpha=0.5)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="238d5e44-c3f4-4cd2-a43d-ed774b40876c"></div>
# </div>

# %%
# Plot winning percentage in terms of expected winning
list_teams = list(dm.Team)
p = figure(plot_width=700, plot_height=400, y_range=(0, 1), x_range=list_teams)
p.circle(y=dm.WP, x=dm.Team, size=5, color="black", alpha=0.5)
p.circle(y=dm.EWP, x=dm.Team, size=5, color="firebrick", alpha=0.5)
#orient x-axis
p.xaxis.major_label_orientation = 1
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d2389bdc-22f0-4dd3-885c-a8cc991ce9ec"></div>
# </div>

# %% [markdown]
# ## Output results

# %%
# convert dataframe to csv
dm.to_csv('mlb_expected.csv')

# %% [markdown]
# Complete
